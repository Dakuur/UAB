# %%
import networkx as nx
import matplotlib.pyplot as plt
import scipy as sp

# %%
G_bfs = nx.read_graphml("G_BFS.graphml")

plt.figure(figsize=(12, 10))

nx.draw(G_bfs, with_labels=True, font_size=4)

plt.show()

# %%
G_dfs = nx.read_graphml("G_DFS.graphml")

plt.figure(figsize=(12, 10))

nx.draw(G_dfs, with_labels=True, font_size=4)

plt.show()

# %%
print(G_bfs)
print(G_dfs)
# Out:
# DiGraph with 442 nodes and 1994 edges
# DiGraph with 596 nodes and 2000 edges
